# %%
import numpy as np
import pandas as pd
import sys
import os
sys.path.append(os.path.abspath('../../..'))
import matplotlib.pyplot as plt
from scripts import nodes as n
from scripts import elements as e
from scripts import material_params as mat
from scipy.linalg import eigh
import plotly.graph_objects as go

# %%
nodes = []
nodal_values = np.loadtxt('../../../text_files/nodes_minimal_model_.txt', delimiter=',')
for i in range(nodal_values.shape[0]):
  nodes.append(n.nodes(nodal_values[i, 0], nodal_values[i, 1], nodal_values[i, 2]))

# %% [markdown]
# # Material parameters

# %%
# Truss parameters
E = 210e9  # Young's modulus in Pascals
nu = 0.3   # Poisson's ratio
G = E / (2 * (1 + nu))  # Shear modulus in Pascals
m = 6.7504 * 10 ** 6 #kg
d1 = 0.8 #m
d2 = 1.8 #m
t1 = 0.03 #m
t2 = 0.08 #m
L_truss_element_y = 15 #m
h_truss = 18 #m
Aeq, Ieqy, Ieqz, b_eq, h_eq = mat.effective_truss_stiffness(d1, d2, t1, t2, h_truss, L_truss_element_y) 
L = 237.5
rho_truss = m / (L * Aeq)
It = (b_eq * h_eq**3 / 3) * (1 - 0.63 * (h_eq / b_eq) * (1 - (h_eq**4 / (12 * b_eq**4)))) *0.06
k = 0.08
Ip  = Ieqy + Ieqz
ep_K = [E, G, Aeq, Ieqy, Ieqz, It, k]
ep_m = [rho_truss, Aeq, Ieqy, Ieqz, Ip]


k = 5/6
rho = 7850 #kg/m^3
E=210e9 #Pa
G = E/(2*(1+nu)) #Pa
nu = 0.3 #Poisson's ratio
k_fender = mat.stiffness_fenders()
Iy_connect, Iz_connect, Ip_connect, It_connect, A_connect = mat.stiffness_connecting_beams()
ep_K_connect = [E, G, A_connect, Iy_connect, Iz_connect, It_connect, k]
ep_m_connect = [rho, A_connect, Iy_connect, Iz_connect, Ip_connect]

# %% [markdown]
# # Sensitivity analysis
#
# A sensitivity study is performed on the increase of the rotational stiffness of the ball-joint in x, y and z direction and in the increase of $I_y$ of the retaining wall.
#
# $I_z$, $I_t$ and $I_p$ depend on $I_y$ and are not changed independently. The following assumptions hold for these parameters:
#
# $$I_z \approx 0.25 I_y  $$
# $$I_t \approx 0.05 I_y  $$
# $$I_p = 0.5 I_y + 0.5 I_z $$
#
# The mass of the retaining wall is 6455148 kg (According to BMK document). Furthermore, a rectangular cross-section is assumed, with height of 22 meters. Therefore, the equivalent Area of the retaining wall is as follows:
#
# $$A_{eq} = I_y \cdot \frac{12}{h^2}$$

# %%
elements = []
element_nodes = np.loadtxt('../../../text_files/element_nodes3.txt', dtype=int)


N = 200
kr_max = 1e13 #N/rad
Iy_max = 10000 #m^4
Iz_max = 0.5 * Iy_max #m^4 
It_max = 0.05 * Iy_max #m^4
Ip_max = Iy_max + Iz_max #m^4
Iy_min = 1500 #m^4
Iz_min = 0.5 * Iy_min #m^4
It_min = 0.05 * Iy_min #m^4
Ip_min = Iy_min + Iz_min #m^4

h = 22 #m
A_eq_max = Iy_max * (12 / h**2) #m^2
A_eq_min = Iy_min * (12 / h**2) #m^2
L = 237.5 #m
m = 6455148 #kg



kr = np.arange(0, kr_max, kr_max / N) 
Iy = np.arange(Iy_min, Iy_max, (Iy_max - Iy_min) / N)
Iz = np.arange(Iz_min, Iz_max, (Iz_max - Iz_min) / N)
It = np.arange(It_min, It_max, (It_max - It_min) / N)
Ip = np.arange(Ip_min, Ip_max, (Ip_max - Ip_min) / N)
A_eq = np.arange(A_eq_min, A_eq_max, (A_eq_max - A_eq_min) / N)
rho = np.zeros(N)
for i in range(N):
    rho[i] = m / (L * A_eq[i])

k = 1 #Shear factor for hollow closed sections

# %% [markdown]
# # Sensitivity analysis run

# %%
param_space = np.zeros((N, N, 10)) # rows are kr and columns are Iy, layers are number of natural frequencies calculated
NN = len(nodes)
DOFS_per_node = 6
fender_dofs = [70, 75, 79, 83, 87, 91, 95, 99, 103, 107, 111, 115, 119, 123, 128]
dofs = n.degrees_of_freedom(nodes)
kr_dofs = [dofs['dof_1'][3], dofs['dof_1'][4], dofs['dof_1'][5]] 



for i in range(len(Iy)):
    ep_K_wall = [E, G, A_eq[i], Iy[i], Iz[i], It[i], k]
    ep_m_wall = [rho[i], A_eq[i], Iy[i], Iz[i], Ip[i]]

    elements = []
    element_nodes = np.loadtxt('../../../text_files/element_nodes3.txt', dtype=int)

    for j in range(element_nodes.shape[0]):
        if element_nodes[j, 2] == 0:
            elements.append(e.elements(nodes[element_nodes[j, 0] - 1], nodes[element_nodes[j, 1] - 1], ep_K, ep_m))
        elif element_nodes[j, 2] == 1:
            elements.append(e.elements(nodes[element_nodes[j, 0] - 1], nodes[element_nodes[j, 1] - 1], ep_K_wall, ep_m_wall))
        elif element_nodes[j, 2] == 2:
            elements.append(e.elements(nodes[element_nodes[j, 0] - 1], nodes[element_nodes[j, 1] - 1], ep_K_connect, ep_m_connect))

    element_nodes = np.loadtxt('../../../text_files/element_nodes.txt', dtype=int)

    element_locs = []

    for (nA, nB) in element_nodes:
        dofs_A = dofs[f'dof_{nA}']
        dofs_B = dofs[f'dof_{nB}']
        element_locs.append(np.hstack((dofs_A, dofs_B)))


    for r in range(len(kr)):
        K_global = np.zeros((NN * DOFS_per_node, NN * DOFS_per_node))
        M_global = np.zeros((NN * DOFS_per_node, NN * DOFS_per_node))

        K_locs = []
        M_locs = []

        for elem in range(len(element_locs)):
            K_global[np.ix_(element_locs[elem], element_locs[elem])] += elements[elem][-1]
            M_global[np.ix_(element_locs[elem], element_locs[elem])] += elements[elem][-2]
        
        K_global = 0.5 * (K_global + K_global.T)
        M_global = 0.5 * (M_global + M_global.T)

        k_fender_dofs = [dofs[f'dof_{kf+1}'][2] for kf in fender_dofs]
        for dof in k_fender_dofs:
            K_global[dof, dof] += k_fender

        for dof in kr_dofs:
            K_global[dof, dof] += kr[r]

        indices_to_remove = np.hstack((dofs['dof_1'][0:3], dofs['dof_129'][0:2]))
        keep_indices = np.setdiff1d(np.arange(NN * DOFS_per_node), indices_to_remove)
        K_global_reduced = K_global[np.ix_(keep_indices, keep_indices)]
        M_global_reduced = M_global[np.ix_(keep_indices, keep_indices)]
        eigvals_global, eigvecs_global = eigh(K_global_reduced, M_global_reduced)   

        tol = 1e-6
        positive = eigvals_global > tol
        eigvals_global = eigvals_global[positive]
        eigvecs_global = eigvecs_global[:, positive]

        frequencies_rad = np.sqrt(eigvals_global)
        frequencies_hz = frequencies_rad / (2 * np.pi)

        param_space[r, i, :] = frequencies_hz[:10]


    print(f'column {i +1} of {len(Iy)} completed')



file_name = f'param_space_N{N}_kr0_{kr_max}_Iy{int(Iy_min)}_{int(Iy_max)}.npy'
np.save(f'runs_kr_Iy_retainingwall/{file_name}', param_space)
# Out:
# column 1 of 200 completed
# column 2 of 200 completed
# column 3 of 200 completed
# column 4 of 200 completed
# column 5 of 200 completed
# column 6 of 200 completed
# column 7 of 200 completed
# column 8 of 200 completed
# column 9 of 200 completed
# column 10 of 200 completed
# column 11 of 200 completed
# column 12 of 200 completed
# column 13 of 200 completed
# column 14 of 200 completed
# column 15 of 200 completed
# column 16 of 200 completed
# column 17 of 200 completed
# column 18 of 200 completed
# column 19 of 200 completed
# column 20 of 200 completed
# column 21 of 200 completed
# column 22 of 200 completed
# column 23 of 200 completed
# column 24 of 200 completed
# column 25 of 200 completed
# column 26 of 200 completed
# column 27 of 200 completed
# column 28 of 200 completed
# column 29 of 200 completed
# column 30 of 200 completed
# column 31 of 200 completed
# column 32 of 200 completed
# column 33 of 200 completed
# column 34 of 200 completed
# column 35 of 200 completed
# column 36 of 200 completed
# column 37 of 200 completed
# column 38 of 200 completed
# column 39 of 200 completed
# column 40 of 200 completed
# column 41 of 200 completed
# column 42 of 200 completed
# column 43 of 200 completed
# column 44 of 200 completed
# column 45 of 200 completed
# column 46 of 200 completed
# column 47 of 200 completed
# column 48 of 200 completed
# column 49 of 200 completed
# column 50 of 200 completed
# column 51 of 200 completed
# column 52 of 200 completed
# column 53 of 200 completed
# column 54 of 200 completed
# column 55 of 200 completed
# column 56 of 200 completed
# column 57 of 200 completed
# column 58 of 200 completed
# column 59 of 200 completed
# column 60 of 200 completed
# column 61 of 200 completed
# column 62 of 200 completed
# column 63 of 200 completed
# column 64 of 200 completed
# column 65 of 200 completed
# column 66 of 200 completed
# column 67 of 200 completed
# column 68 of 200 completed
# column 69 of 200 completed
# column 70 of 200 completed
# column 71 of 200 completed
# column 72 of 200 completed
# column 73 of 200 completed
# column 74 of 200 completed
# column 75 of 200 completed
# column 76 of 200 completed
# column 77 of 200 completed
# column 78 of 200 completed
# column 79 of 200 completed
# column 80 of 200 completed
# column 81 of 200 completed
# column 82 of 200 completed
# column 83 of 200 completed
# column 84 of 200 completed
# column 85 of 200 completed
# column 86 of 200 completed
# column 87 of 200 completed
# column 88 of 200 completed
# column 89 of 200 completed
# column 90 of 200 completed
# column 91 of 200 completed
# column 92 of 200 completed
# column 93 of 200 completed
# column 94 of 200 completed
# column 95 of 200 completed
# column 96 of 200 completed
# column 97 of 200 completed
# column 98 of 200 completed
# column 99 of 200 completed
# column 100 of 200 completed
# column 101 of 200 completed
# column 102 of 200 completed
# column 103 of 200 completed
# column 104 of 200 completed
# column 105 of 200 completed
# column 106 of 200 completed
# column 107 of 200 completed
# column 108 of 200 completed
# column 109 of 200 completed
# column 110 of 200 completed
# column 111 of 200 completed
# column 112 of 200 completed
# column 113 of 200 completed
# column 114 of 200 completed
# column 115 of 200 completed
# column 116 of 200 completed
# column 117 of 200 completed
# column 118 of 200 completed
# column 119 of 200 completed
# column 120 of 200 completed
# column 121 of 200 completed
# column 122 of 200 completed
# column 123 of 200 completed
# column 124 of 200 completed
# column 125 of 200 completed
# column 126 of 200 completed
# column 127 of 200 completed
# column 128 of 200 completed
# column 129 of 200 completed
# column 130 of 200 completed
# column 131 of 200 completed
# column 132 of 200 completed
# column 133 of 200 completed
# column 134 of 200 completed
# column 135 of 200 completed
# column 136 of 200 completed
# column 137 of 200 completed
# column 138 of 200 completed
# column 139 of 200 completed
# column 140 of 200 completed
# column 141 of 200 completed
# column 142 of 200 completed
# column 143 of 200 completed
# column 144 of 200 completed
# column 145 of 200 completed
# column 146 of 200 completed
# column 147 of 200 completed
# column 148 of 200 completed
# column 149 of 200 completed
# column 150 of 200 completed
# column 151 of 200 completed
# column 152 of 200 completed
# column 153 of 200 completed
# column 154 of 200 completed
# column 155 of 200 completed
# column 156 of 200 completed
# column 157 of 200 completed
# column 158 of 200 completed
# column 159 of 200 completed
# column 160 of 200 completed
# column 161 of 200 completed
# column 162 of 200 completed
# column 163 of 200 completed
# column 164 of 200 completed
# column 165 of 200 completed
# column 166 of 200 completed
# column 167 of 200 completed
# column 168 of 200 completed
# column 169 of 200 completed
# column 170 of 200 completed
# column 171 of 200 completed
# column 172 of 200 completed
# column 173 of 200 completed
# column 174 of 200 completed
# column 175 of 200 completed
# column 176 of 200 completed
# column 177 of 200 completed
# column 178 of 200 completed
# column 179 of 200 completed
# column 180 of 200 completed
# column 181 of 200 completed
# column 182 of 200 completed
# column 183 of 200 completed
# column 184 of 200 completed
# column 185 of 200 completed
# column 186 of 200 completed
# column 187 of 200 completed
# column 188 of 200 completed
# column 189 of 200 completed
# column 190 of 200 completed
# column 191 of 200 completed
# column 192 of 200 completed
# column 193 of 200 completed
# column 194 of 200 completed
# column 195 of 200 completed
# column 196 of 200 completed
# column 197 of 200 completed
# column 198 of 200 completed
# column 199 of 200 completed
# column 200 of 200 completed

# %%
freqs_to_plot = 4  # Choose how many natural frequencies to plot
KR, IY = np.meshgrid(kr, Iy, indexing='ij')

for freq_idx in range(min(freqs_to_plot, param_space.shape[2])):
    freq_data = param_space[:, :, freq_idx]
    
    # 2D Color Map
    plt.figure(figsize=(8, 6))
    plt.imshow(freq_data, origin='lower',
               extent=[Iy.min(), Iy.max(), kr.min(), kr.max()],
               aspect='auto')
    plt.colorbar(label=f"Natural Frequency {freq_idx + 1} [Hz]")
    plt.xlabel("Iy")
    plt.ylabel("kr")
    plt.title(f"2D Color Map of Natural Frequency {freq_idx + 1}")
    plt.show()
    
    # 3D Surface Plot
    fig = go.Figure(data=[go.Surface(z=freq_data, x=IY, y=KR, colorscale='Viridis')])
    fig.update_layout(
        title=f'3D Surface of Natural Frequency {freq_idx + 1}',
        scene=dict(
            xaxis_title='Iy',
            yaxis_title='kr',
            zaxis_title=f'Natural Frequency {freq_idx + 1} [Hz]'
        ),
        autosize=True
    )
    fig.show()
