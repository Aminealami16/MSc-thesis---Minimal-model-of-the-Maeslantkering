# %%
import numpy as np
import pandas as pd
import sys
import os
sys.path.append(os.path.abspath('../../..'))
import matplotlib.pyplot as plt
from scripts import nodes as n
from scripts import elements as e
from scripts import material_params as mat
from scipy.linalg import eigh
import plotly.graph_objects as go

# %%
nodes = []
nodal_values = np.loadtxt('../../../text_files/nodes_minimal_model_.txt', delimiter=',')
for i in range(nodal_values.shape[0]):
  nodes.append(n.nodes(nodal_values[i, 0], nodal_values[i, 1], nodal_values[i, 2]))

# %%
# Truss parameters
E = 210e9  # Young's modulus in Pascals
nu = 0.3   # Poisson's ratio
G = E / (2 * (1 + nu))  # Shear modulus in Pascals
m = 5596024 #kg
d1 = 0.8 #m
d2 = 1.8 #m
t1 = 0.03 #m
t2 = 0.08 #m
L_truss_element_y = 15 #m
h_truss = 18 #m
Aeq, Ieqy, Ieqz, b_eq, h_eq = mat.effective_truss_stiffness(d1, d2, t1, t2, h_truss, L_truss_element_y) 
L = 237.5
rho_truss = m / (L * Aeq)
It = (b_eq * h_eq**3 / 3) * (1 - 0.63 * (h_eq / b_eq) * (1 - (h_eq**4 / (12 * b_eq**4)))) *0.06
k = 0.08
Ip  = Ieqy + Ieqz
ep_K = [E, G, Aeq, Ieqy, Ieqz, It, k]
ep_m = [rho_truss, Aeq, Ieqy, Ieqz, Ip]

# %%
k = 5/6
rho = 7850 #kg/m^3
E=210e9 #Pa
G = E/(2*(1+nu)) #Pa
nu = 0.3 #Poisson's ratio
k_fender = mat.stiffness_fenders()
Iy_connect, Iz_connect, Ip_connect, It_connect, A_connect = mat.stiffness_connecting_beams()
ep_K_connect = [E, G, A_connect, Iy_connect, Iz_connect, It_connect, k]
ep_m_connect = [rho, A_connect, Iy_connect, Iz_connect, Ip_connect]


E = 210e9 #Pa
# Material parameters retaining wall
t_eff = 1#m


A_eq_wall, I_eqy_wall, I_eqz_wall, b_eq_wall, rho_wall = mat.effective_retaining_wall_stiffness(t_eff)
Ip_wall = I_eqy_wall + I_eqz_wall
It_wall = (b_eq_wall * t_eff**3 / 3) * (1 - 0.63 * (b_eq_wall / t_eff) + 0.052 * (b_eq_wall / t_eff) **5)

I_eqy_wall = 1e3
I_eqz_wall = 1e3
Ip_wall = I_eqy_wall + I_eqz_wall
It_wall  = 1e3

ep_K_wall = [E, G, A_eq_wall, I_eqy_wall, I_eqz_wall, It_wall, k]
ep_m_wall = [rho_wall, A_eq_wall, I_eqy_wall, I_eqz_wall, Ip_wall]
print(rho_wall)

print(mat.effective_retaining_wall_stiffness(t_eff))
print(mat.effective_truss_stiffness(d1, d2, t1, t2, L_truss_element_y, h_truss))
print(mat.stiffness_connecting_beams())
# Out:
# 458.02196474590005
# (68, 4196.196078431372, 1362.1960784313726, 3.090909090909091, 458.02196474590005)
# (3.17049530600282, 301.6, 256.36, 7.297687177237888, 7.91545310187776)
# (482.5900664338916, 0.32040827013808765, 482.9104747040297, 482.9104747040297, 2.976973198541688)

# %% [markdown]
# # Parameter space for retaining wall stiffness

# %%
N = 1000
I_eqy_wall_max = 1e8
I_eqz_wall_max = 1e8
Ip_wall_max = I_eqy_wall_max + I_eqz_wall_max
It_wall_max = 1e8

Iy = np.arange(I_eqy_wall, I_eqy_wall_max, I_eqy_wall_max/N)
Iz = np.arange(I_eqz_wall, I_eqz_wall_max, I_eqz_wall_max/N)
Ip = np.arange(Ip_wall, Ip_wall_max, Ip_wall_max/N)
It = np.arange(It_wall, It_wall_max, It_wall_max/N)

A_eq_wall_list, I_eqy_wall_list, I_eqz_wall_list, b_eq_wall_list, rho_wall_list = [], [], [], [], []

fig, axs = plt.subplots(2, 2, figsize=(13, 10))

eig_freqs = []
N = len(nodes)
DOFS_per_node = 6

for i in range(len(Iy)):
    A_eq_wall = mat.effective_retaining_wall_stiffness(t_eff)[0]
    I_eqy_wall = Iy[i]
    I_eqz_wall = Iz[i]
    Ip_wall = Ip[i]
    It_wall = It[i]
    rho_wall = mat.effective_retaining_wall_stiffness(t_eff)[4]
    A_eq_wall_list.append(A_eq_wall)
    I_eqy_wall_list.append(I_eqy_wall)
    I_eqz_wall_list.append(I_eqz_wall)
    b_eq_wall_list.append(b_eq_wall)
    rho_wall_list.append(rho_wall)
    ep_K_wall = [E, G, A_eq_wall, I_eqy_wall, I_eqz_wall, It_wall, k]
    ep_m_wall = [rho_wall, A_eq_wall, I_eqy_wall, I_eqz_wall, Ip_wall]  
    
    elements = []
    element_nodes = np.loadtxt('../../../text_files/element_nodes3.txt', dtype=int)
    for ii in range(element_nodes.shape[0]):
        if element_nodes[ii, 2] == 0:
            elements.append(e.elements(nodes[element_nodes[ii, 0] - 1], nodes[element_nodes[ii, 1] - 1], ep_K, ep_m))
        elif element_nodes[ii, 2] == 1:
            elements.append(e.elements(nodes[element_nodes[ii, 0] - 1], nodes[element_nodes[ii, 1] - 1], ep_K_wall, ep_m_wall))
        elif element_nodes[ii, 2] == 2:
            elements.append(e.elements(nodes[element_nodes[ii, 0] - 1], nodes[element_nodes[ii, 1] - 1], ep_K_connect, ep_m_connect))

    element_nodes = np.loadtxt('../../../text_files/element_nodes.txt', dtype=int)


    dofs = n.degrees_of_freedom(nodes)

    element_locs = []

    for (nA, nB) in element_nodes:
        dofs_A = dofs[f'dof_{nA}']
        dofs_B = dofs[f'dof_{nB}']
        element_locs.append(np.hstack((dofs_A, dofs_B)))



    K_global = np.zeros((N * DOFS_per_node, N * DOFS_per_node))
    M_global = np.zeros((N * DOFS_per_node, N * DOFS_per_node))

    K_locs = []
    M_locs = []



    for j in range(len(element_locs)):
        K_global[np.ix_(element_locs[j], element_locs[j])] += elements[j][-1]
        M_global[np.ix_(element_locs[j], element_locs[j])] += elements[j][-2]

    K_global = 0.5 * (K_global + K_global.T)
    M_global = 0.5 * (M_global + M_global.T)

    fender_dofs = [70, 75, 79, 83, 87, 91, 95, 99, 103, 107, 111, 115, 119, 123, 128]
    k_fender_dofs = [dofs[f'dof_{i+1}'][2] for i in fender_dofs]
    for dof in k_fender_dofs:
        K_global[dof, dof] += k_fender 

    indices_to_remove = np.hstack((dofs['dof_1'][0:3], dofs['dof_129'][0:2]))
    keep_indices = np.setdiff1d(np.arange(N * DOFS_per_node), indices_to_remove)
    K_global_reduced = K_global[np.ix_(keep_indices, keep_indices)]
    M_global_reduced = M_global[np.ix_(keep_indices, keep_indices)]

    eigvals_global, eigvecs_global = eigh(K_global_reduced, M_global_reduced)


    tol = 1e-6
    positive = eigvals_global > tol
    eigvals_global = eigvals_global[positive]
    eigvecs_global = eigvecs_global[:, positive]

    frequencies_rad = np.sqrt(eigvals_global)
    frequencies_hz = frequencies_rad / (2 * np.pi)

    eig_freqs.append(frequencies_hz[0:10])

    axs[0, 0].plot(Iy[i], eig_freqs[i][0], '.', color='red')
    axs[0, 1].plot(Iy[i], eig_freqs[i][1], '.', color='red')
    axs[1, 0].plot(Iy[i], eig_freqs[i][2], '.', color='red')
    axs[1, 1].plot(Iy[i], eig_freqs[i][3], '.', color='red')


    print('Loop ', i, 'completed')

for ax in axs.flat:
    ax.grid()
axs[0, 0].set_xlabel('Effective thickness of retaining wall [m]')
axs[0, 1].set_xlabel('Effective thickness of retaining wall [m]')
axs[1, 0].set_xlabel('Effective thickness of retaining wall [m]')
axs[1, 1].set_xlabel('Effective thickness of retaining wall [m]')
axs[0, 0].set_ylabel('Natural frequency [Hz]')
axs[0, 1].set_ylabel('Natural frequency [Hz]')
axs[1, 0].set_ylabel('Natural frequency [Hz]')
axs[1, 1].set_ylabel('Natural frequency [Hz]')
                     
plt.ylabel('Natural frequency [Hz]')
axs[0, 0].set_title('1st natural frequency')
axs[0, 1].set_title('2nd natural frequency')
axs[1, 0].set_title('3rd natural frequency')
axs[1, 1].set_title('4th natural frequency');

# plt.figure()
# plt.plot(Iy, A_eq_wall_list)
# plt.xlabel('Effective thickness of retaining wall [m]')
# plt.ylabel('Effective cross-sectional area [m^2]')
# plt.title('Effective cross-sectional area of retaining wall vs. effective thickness')
# plt.grid()
# plt.show()


# plt.figure()
# plt.plot(Iy, I_eqy_wall_list)
# plt.xlabel('Effective thickness of retaining wall [m]')
# plt.ylabel('Effective moment of inertia about y-axis [m^4]')
# plt.title('Effective moment of inertia about y-axis of retaining wall vs. effective thickness')
# plt.grid()
# plt.show()

# plt.figure()
# plt.plot(Iy, I_eqz_wall_list)
# plt.xlabel('Effective thickness of retaining wall [m]')
# plt.ylabel('Effective moment of inertia about z-axis [m^4]')
# plt.title('Effective moment of inertia about z-axis of retaining wall vs. effective thickness')
# plt.grid()
# plt.show()

# plt.figure()
# plt.plot(Iy, b_eq_wall_list)
# plt.xlabel('Effective thickness of retaining wall [m]')
# plt.ylabel('Equivalent width of retaining wall [m]')
# plt.title('Equivalent width of retaining wall vs. effective thickness')
# plt.grid()
# plt.show()


# plt.plot(Iy, rho_wall_list)
# plt.xlabel('Effective thickness of retaining wall [m]')
# plt.ylabel('Density of retaining wall [kg/m^3]')
# plt.title('Density of retaining wall vs. effective thickness')
# plt.grid()
# plt.show()
# Out:
# Loop  0 completed
# Loop  1 completed
# Loop  2 completed
# Loop  3 completed
# Loop  4 completed
# Loop  5 completed
# Loop  6 completed
# Loop  7 completed
# Loop  8 completed
# Loop  9 completed
# Loop  10 completed
# Loop  11 completed
# Loop  12 completed
# Loop  13 completed
# Loop  14 completed
# Loop  15 completed
# Loop  16 completed
# Loop  17 completed
# Loop  18 completed
# Loop  19 completed
# Loop  20 completed
# Loop  21 completed
# Loop  22 completed
# Loop  23 completed
# Loop  24 completed
# Loop  25 completed
# Loop  26 completed
# Loop  27 completed
# Loop  28 completed
# Loop  29 completed
# Loop  30 completed
# Loop  31 completed
# Loop  32 completed
# Loop  33 completed
# Loop  34 completed
# Loop  35 completed
# Loop  36 completed
# Loop  37 completed
# Loop  38 completed
# Loop  39 completed
# Loop  40 completed
# Loop  41 completed
# Loop  42 completed
# Loop  43 completed
# Loop  44 completed
# Loop  45 completed
# Loop  46 completed
# Loop  47 completed
# Loop  48 completed
# Loop  49 completed
# Loop  50 completed
# Loop  51 completed
# Loop  52 completed
# Loop  53 completed
# Loop  54 completed
# Loop  55 completed
# Loop  56 completed
# Loop  57 completed
# Loop  58 completed
# Loop  59 completed
# Loop  60 completed
# Loop  61 completed
# Loop  62 completed
# Loop  63 completed
# Loop  64 completed
# Loop  65 completed
# Loop  66 completed
# Loop  67 completed
# Loop  68 completed
# Loop  69 completed
# Loop  70 completed
# Loop  71 completed
# Loop  72 completed
# Loop  73 completed
# Loop  74 completed
# Loop  75 completed
# Loop  76 completed
# Loop  77 completed
# Loop  78 completed
# Loop  79 completed
# Loop  80 completed
# Loop  81 completed
# Loop  82 completed
# Loop  83 completed
# Loop  84 completed
# Loop  85 completed
# Loop  86 completed
# Loop  87 completed
# Loop  88 completed
# Loop  89 completed
# Loop  90 completed
# Loop  91 completed
# Loop  92 completed
# Loop  93 completed
# Loop  94 completed
# Loop  95 completed
# Loop  96 completed
# Loop  97 completed
# Loop  98 completed
# Loop  99 completed
# Loop  100 completed
# Loop  101 completed
# Loop  102 completed
# Loop  103 completed
# Loop  104 completed
# Loop  105 completed
# Loop  106 completed
# Loop  107 completed
# Loop  108 completed
# Loop  109 completed
# Loop  110 completed
# Loop  111 completed
# Loop  112 completed
# Loop  113 completed
# Loop  114 completed
# Loop  115 completed
# Loop  116 completed
# Loop  117 completed
# Loop  118 completed
# Loop  119 completed
# Loop  120 completed
# Loop  121 completed
# Loop  122 completed
# Loop  123 completed
# Loop  124 completed
# Loop  125 completed
# Loop  126 completed
# Loop  127 completed
# Loop  128 completed
# Loop  129 completed
# Loop  130 completed
# Loop  131 completed
# Loop  132 completed
# Loop  133 completed
# Loop  134 completed
# Loop  135 completed
# Loop  136 completed
# Loop  137 completed
# Loop  138 completed
# Loop  139 completed
# Loop  140 completed
# Loop  141 completed
# Loop  142 completed
# Loop  143 completed
# Loop  144 completed
# Loop  145 completed
# Loop  146 completed
# Loop  147 completed
# Loop  148 completed
# Loop  149 completed
# Loop  150 completed
# Loop  151 completed
# Loop  152 completed
# Loop  153 completed
# Loop  154 completed
# Loop  155 completed
# Loop  156 completed
# Loop  157 completed
# Loop  158 completed
# Loop  159 completed
# Loop  160 completed
# Loop  161 completed
# Loop  162 completed
# Loop  163 completed
# Loop  164 completed
# Loop  165 completed
# Loop  166 completed
# Loop  167 completed
# Loop  168 completed
# Loop  169 completed
# Loop  170 completed
# Loop  171 completed
# Loop  172 completed
# Loop  173 completed
# Loop  174 completed
# Loop  175 completed
# Loop  176 completed
# Loop  177 completed
# Loop  178 completed
# Loop  179 completed
# Loop  180 completed
# Loop  181 completed
# Loop  182 completed
# Loop  183 completed
# Loop  184 completed
# Loop  185 completed
# Loop  186 completed
# Loop  187 completed
# Loop  188 completed
# Loop  189 completed
# Loop  190 completed
# Loop  191 completed
# Loop  192 completed
# Loop  193 completed
# Loop  194 completed
# Loop  195 completed
# Loop  196 completed
# Loop  197 completed
# Loop  198 completed
# Loop  199 completed
# Loop  200 completed
# Loop  201 completed
# Loop  202 completed
# Loop  203 completed
# Loop  204 completed
# Loop  205 completed
# Loop  206 completed
# Loop  207 completed
# Loop  208 completed
# Loop  209 completed
# Loop  210 completed
# Loop  211 completed
# Loop  212 completed
# Loop  213 completed
# Loop  214 completed
# Loop  215 completed
# Loop  216 completed
# Loop  217 completed
# Loop  218 completed
# Loop  219 completed
# Loop  220 completed
# Loop  221 completed
# Loop  222 completed
# Loop  223 completed
# Loop  224 completed
# Loop  225 completed
# Loop  226 completed
# Loop  227 completed
# Loop  228 completed
# Loop  229 completed
# Loop  230 completed
# Loop  231 completed
# Loop  232 completed
# Loop  233 completed
# Loop  234 completed
# Loop  235 completed
# Loop  236 completed
# Loop  237 completed
# Loop  238 completed
# Loop  239 completed
# Loop  240 completed
# Loop  241 completed
# Loop  242 completed
# Loop  243 completed
# Loop  244 completed
# Loop  245 completed
# Loop  246 completed
# Loop  247 completed
# Loop  248 completed
# Loop  249 completed
# Loop  250 completed
# Loop  251 completed
# Loop  252 completed
# Loop  253 completed
# Loop  254 completed
# Loop  255 completed
# Loop  256 completed
# Loop  257 completed
# Loop  258 completed
# Loop  259 completed
# Loop  260 completed
# Loop  261 completed
# Loop  262 completed
# Loop  263 completed
# Loop  264 completed
# Loop  265 completed
# Loop  266 completed
# Loop  267 completed
# Loop  268 completed
# Loop  269 completed
# Loop  270 completed
# Loop  271 completed
# Loop  272 completed
# Loop  273 completed
# Loop  274 completed
# Loop  275 completed
# Loop  276 completed
# Loop  277 completed
# Loop  278 completed
# Loop  279 completed
# Loop  280 completed
# Loop  281 completed
# Loop  282 completed
# Loop  283 completed
# Loop  284 completed
# Loop  285 completed
# Loop  286 completed
# Loop  287 completed
# Loop  288 completed
# Loop  289 completed
# Loop  290 completed
# Loop  291 completed
# Loop  292 completed
# Loop  293 completed
# Loop  294 completed
# Loop  295 completed
# Loop  296 completed
# Loop  297 completed
# Loop  298 completed
# Loop  299 completed
# Loop  300 completed
# Loop  301 completed
# Loop  302 completed
# Loop  303 completed
# Loop  304 completed
# Loop  305 completed
# Loop  306 completed
# Loop  307 completed
# Loop  308 completed
# Loop  309 completed
# Loop  310 completed
# Loop  311 completed
# Loop  312 completed
# Loop  313 completed
# Loop  314 completed
# Loop  315 completed
# Loop  316 completed
# Loop  317 completed
# Loop  318 completed
# Loop  319 completed
# Loop  320 completed
# Loop  321 completed
# Loop  322 completed
# Loop  323 completed
# Loop  324 completed
# Loop  325 completed
# Loop  326 completed
# Loop  327 completed
# Loop  328 completed
# Loop  329 completed
# Loop  330 completed
# Loop  331 completed
# Loop  332 completed
# Loop  333 completed
# Loop  334 completed
# Loop  335 completed
# Loop  336 completed
# Loop  337 completed
# Loop  338 completed
# Loop  339 completed
# Loop  340 completed
# Loop  341 completed
# Loop  342 completed
# Loop  343 completed
# Loop  344 completed
# Loop  345 completed
# Loop  346 completed
# Loop  347 completed
# Loop  348 completed
# Loop  349 completed
# Loop  350 completed
# Loop  351 completed
# Loop  352 completed
# Loop  353 completed
# Loop  354 completed
# Loop  355 completed
# Loop  356 completed
# Loop  357 completed
# Loop  358 completed
# Loop  359 completed
# Loop  360 completed
# Loop  361 completed
# Loop  362 completed
# Loop  363 completed
# Loop  364 completed
# Loop  365 completed
# Loop  366 completed
# Loop  367 completed
# Loop  368 completed
# Loop  369 completed
# Loop  370 completed
# Loop  371 completed
# Loop  372 completed
# Loop  373 completed
# Loop  374 completed
# Loop  375 completed
# Loop  376 completed
# Loop  377 completed
# Loop  378 completed
# Loop  379 completed
# Loop  380 completed
# Loop  381 completed
# Loop  382 completed
# Loop  383 completed
# Loop  384 completed
# Loop  385 completed
# Loop  386 completed
# Loop  387 completed
# Loop  388 completed
# Loop  389 completed
# Loop  390 completed
# Loop  391 completed
# Loop  392 completed
# Loop  393 completed
# Loop  394 completed
# Loop  395 completed
# Loop  396 completed
# Loop  397 completed
# Loop  398 completed
# Loop  399 completed
# Loop  400 completed
# Loop  401 completed
# Loop  402 completed
# Loop  403 completed
# Loop  404 completed
# Loop  405 completed
# Loop  406 completed
# Loop  407 completed
# Loop  408 completed
# Loop  409 completed
# Loop  410 completed
# Loop  411 completed
# Loop  412 completed
# Loop  413 completed
# Loop  414 completed
# Loop  415 completed
# Loop  416 completed
# Loop  417 completed
# Loop  418 completed
# Loop  419 completed
# Loop  420 completed
# Loop  421 completed
# Loop  422 completed
# Loop  423 completed
# Loop  424 completed
# Loop  425 completed
# Loop  426 completed
# Loop  427 completed
# Loop  428 completed
# Loop  429 completed
# Loop  430 completed
# Loop  431 completed
# Loop  432 completed
# Loop  433 completed
# Loop  434 completed
# Loop  435 completed
# Loop  436 completed
# Loop  437 completed
# Loop  438 completed
# Loop  439 completed
# Loop  440 completed
# Loop  441 completed
# Loop  442 completed
# Loop  443 completed
# Loop  444 completed
# Loop  445 completed
# Loop  446 completed
# Loop  447 completed
# Loop  448 completed
# Loop  449 completed
# Loop  450 completed
# Loop  451 completed
# Loop  452 completed
# Loop  453 completed
# Loop  454 completed
# Loop  455 completed
# Loop  456 completed
# Loop  457 completed
# Loop  458 completed
# Loop  459 completed
# Loop  460 completed
# Loop  461 completed
# Loop  462 completed
# Loop  463 completed
# Loop  464 completed
# Loop  465 completed
# Loop  466 completed
# Loop  467 completed
# Loop  468 completed
# Loop  469 completed
# Loop  470 completed
# Loop  471 completed
# Loop  472 completed
# Loop  473 completed
# Loop  474 completed
# Loop  475 completed
# Loop  476 completed
# Loop  477 completed
# Loop  478 completed
# Loop  479 completed
# Loop  480 completed
# Loop  481 completed
# Loop  482 completed
# Loop  483 completed
# Loop  484 completed
# Loop  485 completed
# Loop  486 completed
# Loop  487 completed
# Loop  488 completed
# Loop  489 completed
# Loop  490 completed
# Loop  491 completed
# Loop  492 completed
# Loop  493 completed
# Loop  494 completed
# Loop  495 completed
# Loop  496 completed
# Loop  497 completed
# Loop  498 completed
# Loop  499 completed
# Loop  500 completed
# Loop  501 completed
# Loop  502 completed
# Loop  503 completed
# Loop  504 completed
# Loop  505 completed
# Loop  506 completed
# Loop  507 completed
# Loop  508 completed
# Loop  509 completed
# Loop  510 completed
# Loop  511 completed
# Loop  512 completed
# Loop  513 completed
# Loop  514 completed
# Loop  515 completed
# Loop  516 completed
# Loop  517 completed
# Loop  518 completed
# Loop  519 completed
# Loop  520 completed
# Loop  521 completed
# Loop  522 completed
# Loop  523 completed
# Loop  524 completed
# Loop  525 completed
# Loop  526 completed
# Loop  527 completed
# Loop  528 completed
# Loop  529 completed
# Loop  530 completed
# Loop  531 completed
# Loop  532 completed
# Loop  533 completed
# Loop  534 completed
# Loop  535 completed
# Loop  536 completed
# Loop  537 completed
# Loop  538 completed
# Loop  539 completed
# Loop  540 completed
# Loop  541 completed
# Loop  542 completed
# Loop  543 completed
# Loop  544 completed
# Loop  545 completed
# Loop  546 completed
# Loop  547 completed
# Loop  548 completed
# Loop  549 completed
# Loop  550 completed
# Loop  551 completed
# Loop  552 completed
# Loop  553 completed
# Loop  554 completed
# Loop  555 completed
# Loop  556 completed
# Loop  557 completed
# Loop  558 completed
# Loop  559 completed
# Loop  560 completed
# Loop  561 completed
# Loop  562 completed
# Loop  563 completed
# Loop  564 completed
# Loop  565 completed
# Loop  566 completed
# Loop  567 completed
# Loop  568 completed
# Loop  569 completed
# Loop  570 completed
# Loop  571 completed
# Loop  572 completed
# Loop  573 completed
# Loop  574 completed
# Loop  575 completed
# Loop  576 completed
# Loop  577 completed
# Loop  578 completed
# Loop  579 completed
# Loop  580 completed
# Loop  581 completed
# Loop  582 completed
# Loop  583 completed
# Loop  584 completed
# Loop  585 completed
# Loop  586 completed
# Loop  587 completed
# Loop  588 completed
# Loop  589 completed
# Loop  590 completed
# Loop  591 completed
# Loop  592 completed
# Loop  593 completed
# Loop  594 completed
# Loop  595 completed
# Loop  596 completed
# Loop  597 completed
# Loop  598 completed
# Loop  599 completed
# Loop  600 completed
# Loop  601 completed
# Loop  602 completed
# Loop  603 completed
# Loop  604 completed
# Loop  605 completed
# Loop  606 completed
# Loop  607 completed
# Loop  608 completed
# Loop  609 completed
# Loop  610 completed
# Loop  611 completed
# Loop  612 completed
# Loop  613 completed
# Loop  614 completed
# Loop  615 completed
# Loop  616 completed
# Loop  617 completed
# Loop  618 completed
# Loop  619 completed
# Loop  620 completed
# Loop  621 completed
# Loop  622 completed
# Loop  623 completed
# Loop  624 completed
# Loop  625 completed
# Loop  626 completed
# Loop  627 completed
# Loop  628 completed
# Loop  629 completed
# Loop  630 completed
# Loop  631 completed
# Loop  632 completed
# Loop  633 completed
# Loop  634 completed
# Loop  635 completed
# Loop  636 completed
# Loop  637 completed
# Loop  638 completed
# Loop  639 completed
# Loop  640 completed
# Loop  641 completed
# Loop  642 completed
# Loop  643 completed
# Loop  644 completed
# Loop  645 completed
# Loop  646 completed
# Loop  647 completed
# Loop  648 completed
# Loop  649 completed
# Loop  650 completed
# Loop  651 completed
# Loop  652 completed
# Loop  653 completed
# Loop  654 completed
# Loop  655 completed
# Loop  656 completed
# Loop  657 completed
# Loop  658 completed
# Loop  659 completed
# Loop  660 completed
# Loop  661 completed
# Loop  662 completed
# Loop  663 completed
# Loop  664 completed
# Loop  665 completed
# Loop  666 completed
# Loop  667 completed
# Loop  668 completed
# Loop  669 completed
# Loop  670 completed
# Loop  671 completed
# Loop  672 completed
# Loop  673 completed
# Loop  674 completed
# Loop  675 completed
# Loop  676 completed
# Loop  677 completed
# Loop  678 completed
# Loop  679 completed
# Loop  680 completed
# Loop  681 completed
# Loop  682 completed
# Loop  683 completed
# Loop  684 completed
# Loop  685 completed
# Loop  686 completed
# Loop  687 completed
# Loop  688 completed
# Loop  689 completed
# Loop  690 completed
# Loop  691 completed
# Loop  692 completed
# Loop  693 completed
# Loop  694 completed
# Loop  695 completed
# Loop  696 completed
# Loop  697 completed
# Loop  698 completed
# Loop  699 completed
# Loop  700 completed
# Loop  701 completed
# Loop  702 completed
# Loop  703 completed
# Loop  704 completed
# Loop  705 completed
# Loop  706 completed
# Loop  707 completed
# Loop  708 completed
# Loop  709 completed
# Loop  710 completed
# Loop  711 completed
# Loop  712 completed
# Loop  713 completed
# Loop  714 completed
# Loop  715 completed
# Loop  716 completed
# Loop  717 completed
# Loop  718 completed
# Loop  719 completed
# Loop  720 completed
# Loop  721 completed
# Loop  722 completed
# Loop  723 completed
# Loop  724 completed
# Loop  725 completed
# Loop  726 completed
# Loop  727 completed
# Loop  728 completed
# Loop  729 completed
# Loop  730 completed
# Loop  731 completed
# Loop  732 completed
# Loop  733 completed
# Loop  734 completed
# Loop  735 completed
# Loop  736 completed
# Loop  737 completed
# Loop  738 completed
# Loop  739 completed
# Loop  740 completed
# Loop  741 completed
# Loop  742 completed
# Loop  743 completed
# Loop  744 completed
# Loop  745 completed
# Loop  746 completed
# Loop  747 completed
# Loop  748 completed
# Loop  749 completed
# Loop  750 completed
# Loop  751 completed
# Loop  752 completed
# Loop  753 completed
# Loop  754 completed
# Loop  755 completed
# Loop  756 completed
# Loop  757 completed
# Loop  758 completed
# Loop  759 completed
# Loop  760 completed
# Loop  761 completed
# Loop  762 completed
# Loop  763 completed
# Loop  764 completed
# Loop  765 completed
# Loop  766 completed
# Loop  767 completed
# Loop  768 completed
# Loop  769 completed
# Loop  770 completed
# Loop  771 completed
# Loop  772 completed
# Loop  773 completed
# Loop  774 completed
# Loop  775 completed
# Loop  776 completed
# Loop  777 completed
# Loop  778 completed
# Loop  779 completed
# Loop  780 completed
# Loop  781 completed
# Loop  782 completed
# Loop  783 completed
# Loop  784 completed
# Loop  785 completed
# Loop  786 completed
# Loop  787 completed
# Loop  788 completed
# Loop  789 completed
# Loop  790 completed
# Loop  791 completed
# Loop  792 completed
# Loop  793 completed
# Loop  794 completed
# Loop  795 completed
# Loop  796 completed
# Loop  797 completed
# Loop  798 completed
# Loop  799 completed
# Loop  800 completed
# Loop  801 completed
# Loop  802 completed
# Loop  803 completed
# Loop  804 completed
# Loop  805 completed
# Loop  806 completed
# Loop  807 completed
# Loop  808 completed
# Loop  809 completed
# Loop  810 completed
# Loop  811 completed
# Loop  812 completed
# Loop  813 completed
# Loop  814 completed
# Loop  815 completed
# Loop  816 completed
# Loop  817 completed
# Loop  818 completed
# Loop  819 completed
# Loop  820 completed
# Loop  821 completed
# Loop  822 completed
# Loop  823 completed
# Loop  824 completed
# Loop  825 completed
# Loop  826 completed
# Loop  827 completed
# Loop  828 completed
# Loop  829 completed
# Loop  830 completed
# Loop  831 completed
# Loop  832 completed
# Loop  833 completed
# Loop  834 completed
# Loop  835 completed
# Loop  836 completed
# Loop  837 completed
# Loop  838 completed
# Loop  839 completed
# Loop  840 completed
# Loop  841 completed
# Loop  842 completed
# Loop  843 completed
# Loop  844 completed
# Loop  845 completed
# Loop  846 completed
# Loop  847 completed
# Loop  848 completed
# Loop  849 completed
# Loop  850 completed
# Loop  851 completed
# Loop  852 completed
# Loop  853 completed
# Loop  854 completed
# Loop  855 completed
# Loop  856 completed
# Loop  857 completed
# Loop  858 completed
# Loop  859 completed
# Loop  860 completed
# Loop  861 completed
# Loop  862 completed
# Loop  863 completed
# Loop  864 completed
# Loop  865 completed
# Loop  866 completed
# Loop  867 completed
# Loop  868 completed
# Loop  869 completed
# Loop  870 completed
# Loop  871 completed
# Loop  872 completed
# Loop  873 completed
# Loop  874 completed
# Loop  875 completed
# Loop  876 completed
# Loop  877 completed
# Loop  878 completed
# Loop  879 completed
# Loop  880 completed
# Loop  881 completed
# Loop  882 completed
# Loop  883 completed
# Loop  884 completed
# Loop  885 completed
# Loop  886 completed
# Loop  887 completed
# Loop  888 completed
# Loop  889 completed
# Loop  890 completed
# Loop  891 completed
# Loop  892 completed
# Loop  893 completed
# Loop  894 completed
# Loop  895 completed
# Loop  896 completed
# Loop  897 completed
# Loop  898 completed
# Loop  899 completed
# Loop  900 completed
# Loop  901 completed
# Loop  902 completed
# Loop  903 completed
# Loop  904 completed
# Loop  905 completed
# Loop  906 completed
# Loop  907 completed
# Loop  908 completed
# Loop  909 completed
# Loop  910 completed
# Loop  911 completed
# Loop  912 completed
# Loop  913 completed
# Loop  914 completed
# Loop  915 completed
# Loop  916 completed
# Loop  917 completed
# Loop  918 completed
# Loop  919 completed
# Loop  920 completed
# Loop  921 completed
# Loop  922 completed
# Loop  923 completed
# Loop  924 completed
# Loop  925 completed
# Loop  926 completed
# Loop  927 completed
# Loop  928 completed
# Loop  929 completed
# Loop  930 completed
# Loop  931 completed
# Loop  932 completed
# Loop  933 completed
# Loop  934 completed
# Loop  935 completed
# Loop  936 completed
# Loop  937 completed
# Loop  938 completed
# Loop  939 completed
# Loop  940 completed
# Loop  941 completed
# Loop  942 completed
# Loop  943 completed
# Loop  944 completed
# Loop  945 completed
# Loop  946 completed
# Loop  947 completed
# Loop  948 completed
# Loop  949 completed
# Loop  950 completed
# Loop  951 completed
# Loop  952 completed
# Loop  953 completed
# Loop  954 completed
# Loop  955 completed
# Loop  956 completed
# Loop  957 completed
# Loop  958 completed
# Loop  959 completed
# Loop  960 completed
# Loop  961 completed
# Loop  962 completed
# Loop  963 completed
# Loop  964 completed
# Loop  965 completed
# Loop  966 completed
# Loop  967 completed
# Loop  968 completed
# Loop  969 completed
# Loop  970 completed
# Loop  971 completed
# Loop  972 completed
# Loop  973 completed
# Loop  974 completed
# Loop  975 completed
# Loop  976 completed
# Loop  977 completed
# Loop  978 completed
# Loop  979 completed
# Loop  980 completed
# Loop  981 completed
# Loop  982 completed
# Loop  983 completed
# Loop  984 completed
# Loop  985 completed
# Loop  986 completed
# Loop  987 completed
# Loop  988 completed
# Loop  989 completed
# Loop  990 completed
# Loop  991 completed
# Loop  992 completed
# Loop  993 completed
# Loop  994 completed
# Loop  995 completed
# Loop  996 completed
# Loop  997 completed
# Loop  998 completed
# Loop  999 completed
